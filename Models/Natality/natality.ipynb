# %% [markdown]
# # MODELO DE PREDICCIÓN PARA LA NATALIDAD
# **Variable objetivo:** natalidad ó número de nacimientos.
#
# **Variable spredictoras:** númeor de personas según sexo y franja de edad. Rangos de edad de 5 años, siendo el primero 0-4 años y el último >100 años.

# %% [markdown]
# ## Startup

# %% [markdown]
# Mount the Google Drive to Google Colab:

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/MyDrive/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Import some libraries:

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# Read data:

# %%
df_02 = pd.read_excel(path + "EXCEL_02.xlsx", converters = {'CODMUN' : str})
df_04 = pd.read_excel(path + "EXCEL_04.xlsx", converters = {'CODMUN' : str})
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/worksheet/header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
df_02.head()
# Out:
#   CODMUN Provincia         Municipio  NAT2000  NAT2001  NAT2002  NAT2003  \
# 0  01001     Alava  Alegría-Dulantzi     29.0     25.0     27.0     34.0
# 1  01002     Alava           Amurrio     72.0     66.0     54.0     68.0
# 2  01003     Alava           Aramaio     15.0     18.0     15.0     17.0
# 3  01004     Alava        Artziniega     12.0     13.0     12.0     20.0
# 4  01006     Alava           Armiñón      1.0      4.0      0.0      3.0
#
#    NAT2004  NAT2005  NAT2006  NAT2007  NAT2008  NAT2009  NAT2010  NAT2011  \
# 0     34.0     47.0       38       52       62       33       47       37
# 1     67.0     61.0       81       95       87       85       93      104
# 2     19.0     17.0       19       10       15       15       14       13
# 3     12.0     17.0       17       24       16       23       28       35
# 4      2.0      2.0        5        2        2        3        2        2
#
#    NAT2012  NAT2013  NAT2014  NAT2015  NAT2016  NAT2017  NAT2018  NAT2019  \
# 0       34       34       42       30       29       22       17       25
# 1      105      109       99      121      112      104       87       74
# 2       12       12       20       11        8       16        9       11
# 3       26       19       16       19       21       16       14       11
# 4        3        5        2        2        0        1        0        0
#
#    NAT2020  MOR2000  MOR2001  MOR2002  MOR2003  MOR2004  MOR2005  MOR2006  \
# 0       17     10.0      9.0      4.0     14.0      9.0     15.0        5
# 1       85     65.0     73.0     68.0     74.0     79.0     83.0       78
# 2        5      9.0      6.0     12.0     16.0      7.0     12.0       11
# 3       15     11.0     10.0      8.0     14.0     14.0     19.0       10
# 4        1      2.0      1.0      0.0      2.0      0.0      2.0        3
#
#    MOR2007  MOR2008  MOR2009  MOR2010  MOR2011  MOR2012  MOR2013  MOR2014  \
# 0       10       10       13        3       14       14       13       23
# 1       83       87       84       79       88      100       85       75
# 2       14       16       18       12       10       17       12        9
# 3       21       12       20       14       13       14       15       13
# 4        0        1        1        2        3        2        0        5
#
#    MOR2015  MOR2016  MOR2017  MOR2018  MOR2019  MOR2020  SVEG2000  SVEG2001  \
# 0       18       13       14       15       12       11        19        16
# 1       93      101      106       97       95       98         7        -7
# 2       13       11       12       21       16       18         6        12
# 3       21       21       23       20       14       17         1         3
# 4        1        2        5        1        2        2        -1         3
#
#    SVEG2002  SVEG2003  SVEG2004  SVEG2005  SVEG2006  SVEG2007  SVEG2008  \
# 0        23        20        25        32        33        42        52
# 1       -14        -6       -12       -22         3        12         0
# 2         3         1        12         5         8        -4        -1
# 3         4         6        -2        -2         7         3         4
# 4         0         1         2         0         2         2         1
#
#    SVEG2009  SVEG2010  SVEG2011  SVEG2012  SVEG2013  SVEG2014  SVEG2015  \
# 4     414   92.783505  181.081081  365.000000  33.396584      352  12.500000
#
#      PRMEF10  MEFEC10   HIJMUJ10    PRMEF21  MEFEC21   HIJMUJ21  CARMAT03  \
# 0  64.457831      642   5.451713  24.756098      203  15.763547  4.166667
# 1  68.523154     4380   6.689498  29.864426     1564  15.345269  5.980392
# 2  57.783641      219   4.566210  28.136882       74   4.054054  8.783784
# 3  74.155074    32517  10.170065  29.000542    11769  18.582717  7.164179
# 4  62.462159      619   8.400646  28.571429      250  16.800000  6.818182
#
#    CARMAT10  CARMAT21  POB2021  POB2010  POB2003  HOM2021  HOM2010  HOM2003  \
# 0  2.647975  8.866995     1620     2031   2296.0      800     1035   1191.0
# 1  3.059361  7.352941    10346    12582  14366.0     5109     6190   7047.0
# 2  2.739726  1.351351      616      805    883.0      353      426    471.0
# 3  4.926654  9.117172    76874    84202  84182.0    36292    40352  40374.0
# 4  4.361874  9.600000     1691     1894   2008.0      816      903    954.0
#
#    MUJ2021  MUJ2010  MUJ2003
# 0      820      996   1105.0
# 1     5237     6392   7319.0
# 2      263      379    412.0
# 3    40582    43850  43808.0
# 4      875      991   1054.0

# %% [markdown]
# Select target variables (NAT2003, NAT2010) and comunn CODMUN for future merge:

# %%
my_02_cols = ["NAT2003", "NAT2010"]
my_02_cols.append("CODMUN")
my_02_cols
# Out:
# ['NAT2003', 'NAT2010', 'CODMUN']

# %% [markdown]
# Select predictors and column CODMUN ofr future merge:

# %%
my_04_cols = list(filter(lambda x: (x[-3:] == "_03" or x[-3:] == "_10") and
                                   (x[0] == "M" or x[0] == "H"), df_04.columns))
my_04_cols.append("CODMUN")
my_04_cols
# Out:
# ['H0A4_10',
#  'H0A4_03',
#  'H5A9_10',
#  'H5A9_03',
#  'H10A14_10',
#  'H10A14_03',
#  'H15A19_10',
#  'H15A19_03',
#  'H20A24_10',
#  'H20A24_03',
#  'H25A29_10',
#  'H25A29_03',
#  'H30A34_10',
#  'H30A34_03',
#  'H35A39_10',
#  'H35A39_03',
#  'H40A44_10',
#  'H40A44_03',
#  'H45A49_10',
#  'H45A49_03',
#  'H50A54_10',
#  'H50A54_03',
#  'H55A59_10',
#  'H55A59_03',
#  'H60A64_10',
#  'H60A64_03',
#  'H65A69_10',
#  'H65A69_03',
#  'H70A74_10',
#  'H70A74_03',
#  'H75A79_10',
#  'H75A79_03',
#  'H80A84_10',
#  'H80A84_03',
#  'H85A89_10',
#  'H85A89_03',
#  'H90A94_10',
#  'H90A94_03',
#  'H95A99_10',
#  'H95A99_03',
#  'H100MS_10',
#  'H100MS_03',
#  'M0A4_10',
#  'M0A4_03',
#  'M5A9_10',
#  'M5A9_03',
#  'M10A14_10',
#  'M10A14_03',
#  'M15A19_10',
#  'M15A19_03',
#  'M20A24_10',
#  'M20A24_03',
#  'M25A29_10',
#  'M25A29_03',
#  'M30A34_10',
#  'M30A34_03',
#  'M35A39_10',
#  'M35A39_03',
#  'M40A44_10',
#  'M40A44_03',
#  'M45A49_10',
#  'M45A49_03',
#  'M50A54_10',
#  'M50A54_03',
#  'M55A59_10',
#  'M55A59_03',
#  'M60A64_10',
#  'M60A64_03',
#  'M65A69_10',
#  'M65A69_03',
#  'M70A74_10',
#  'M70A74_03',
#  'M75A79_10',
#  'M75A79_03',
#  'M80A84_10',
#  'M80A84_03',
#  'M85A89_10',
#  'M85A89_03',
#  'M90A94_10',
#  'M90A94_03',
#  'M95A99_10',
#  'M95A99_03',
#  'M100YMS_10',
#  'M100YMS_03',
#  'CODMUN']

# %% [markdown]
# Check shapes:

# %%
df_02.shape
# Out:
# (3856, 150)

# %%
df_04.shape
# Out:
# (3931, 267)

# %% [markdown]
# Have a look at the population centres that are not in both datasets:

# %%
temp1 = list(df_04["CODMUN"].values)
temp2 = list(df_02["CODMUN"].values)
print(len([elem for elem in temp1 if elem not in temp2]))
print(len([elem for elem in temp2 if elem not in temp1]))
# Out:
# 75
# 0

# %% [markdown]
# Perform outer join in order to return all those records wich either have a match in the left or right dataframe:

# %%
df_join = pd.merge(df_02[my_02_cols], df_04[my_04_cols], 
             on = "CODMUN",
             how = "outer")

# %%
df_join.shape
# Out:
# (3931, 87)

# %% [markdown]
# Remove rows with missing values

# %%
df_join.isnull().any(axis=1).sum()
# Out:
# 77

# %%
df_join = df_join.dropna()

# %%
df_join.shape
# Out:
# (3854, 87)

# %% [markdown]
# We do not need CODMUN anymore so drop it:

# %%
df_join = df_join.drop(["CODMUN"], axis = 1)

# %%
df_join.head()
# Out:
#    NAT2003  NAT2010  H0A4_10  H0A4_03  H5A9_10  H5A9_03  H10A14_10  H10A14_03  \
# 0     34.0     47.0    118.0     64.0    104.0     32.0       53.0       41.0
# 1     68.0     93.0    236.0    155.0    192.0    175.0      205.0      231.0
# 2     17.0     14.0     43.0     39.0     42.0     36.0       41.0       39.0
# 3     20.0     28.0     53.0     25.0     55.0     32.0       44.0       36.0
# 4      3.0      2.0      9.0      4.0      3.0      4.0        2.0        1.0
#
#    H15A19_10  H15A19_03  H20A24_10  H20A24_03  H25A29_10  H25A29_03  \
# 0       48.0       36.0       46.0       52.0       80.0       96.0
# 1      221.0      276.0      294.0      420.0      379.0      370.0
# 2       29.0       38.0       35.0       41.0       35.0       47.0
# 3       39.0       38.0       40.0       45.0       57.0       54.0
# 4        4.0        2.0        3.0        1.0        2.0        6.0
#
#    H30A34_10  H30A34_03  H35A39_10  H35A39_03  H40A44_10  H40A44_03  \
# 0      172.0      124.0      204.0       98.0      148.0       69.0
# 1      444.0      321.0      346.0      380.0      409.0      412.0
# 2       48.0       59.0       65.0       73.0       60.0       76.0
# 3      110.0       56.0       82.0       63.0       72.0       60.0
# 4       10.0       11.0       19.0        8.0        9.0       10.0
#
#    H45A49_10  H45A49_03  H50A54_10  H50A54_03  H55A59_10  H55A59_03  \
# 0      119.0       57.0       73.0       53.0       71.0       44.0
# 1      418.0      359.0      400.0      427.0      395.0      318.0
# 2       72.0       68.0       70.0       45.0       57.0       48.0
# 3       72.0       60.0       60.0       44.0       67.0       40.0
# 4       16.0        5.0        6.0        6.0        3.0        2.0
#
#    H60A64_10  H60A64_03  H65A69_10  H65A69_03  H70A74_10  H70A74_03  \
# 0       12.0       24.0       13.0        6.0        7.0        6.0
# 1      178.0      136.0      108.0       67.0       36.0       25.0
# 2       24.0       24.0       12.0       10.0        9.0        7.0
# 3       25.0       22.0       27.0       11.0       10.0        4.0
# 4        2.0        4.0        3.0        0.0        0.0        0.0
#
#    M95A99_10  M95A99_03  M100YMS_10  M100YMS_03
# 0        0.0        5.0         1.0         0.0
# 1        8.0        6.0         0.0         2.0
# 2        3.0        1.0         0.0         0.0
# 3        4.0        0.0         1.0         0.0
# 4        0.0        0.0         0.0         0.0

# %% [markdown]
# Select columns for years 2003 and 2010:

# %%
df_join_03_cols = [elem for elem in df_join.columns if elem[-2:] == "03"]
df_join_10_cols = [elem for elem in df_join.columns if elem[-2:] == "10"]

# %%
df_join_03 = df_join[df_join_03_cols]
df_join_03.head()
# Out:
#    NAT2003  H0A4_03  H5A9_03  H10A14_03  H15A19_03  H20A24_03  H25A29_03  \
# 0     34.0     64.0     32.0       41.0       36.0       52.0       96.0
# 1     68.0    155.0    175.0      231.0      276.0      420.0      370.0
# 2     17.0     39.0     36.0       39.0       38.0       41.0       47.0
# 3     20.0     25.0     32.0       36.0       38.0       45.0       54.0
# 4      3.0      4.0      4.0        1.0        2.0        1.0        6.0
#
#    H30A34_03  H35A39_03  H40A44_03  H45A49_03  H50A54_03  H55A59_03  \
# 0      124.0       98.0       69.0       57.0       53.0       44.0
# 1      321.0      380.0      412.0      359.0      427.0      318.0
# 2       59.0       73.0       76.0       68.0       45.0       48.0
# 3       56.0       63.0       60.0       60.0       44.0       40.0
# 4       11.0        8.0       10.0        5.0        6.0        2.0
#
#    H60A64_03  H65A69_03  H70A74_03  H75A79_03  H80A84_03  H85A89_03  \
# 0       36.0       28.0       24.0       14.0        7.0        5.0
# 1      203.0      211.0      207.0      143.0       86.0       36.0
# 2       38.0       53.0       39.0       19.0       14.0       15.0
# 3       25.0       30.0       30.0       14.0       21.0        2.0
# 4        5.0        8.0        6.0        4.0        2.0        1.0
#
#    H90A94_03  H95A99_03  H100MS_03  M0A4_03  M5A9_03  M10A14_03  M15A19_03  \
# 0        5.0        0.0        0.0     61.0     42.0       40.0       35.0
# 1       11.0        2.0        0.0    176.0    173.0      217.0      291.0
# 2        2.0        0.0        0.0     33.0     28.0       31.0       38.0
# 3        4.0        0.0        0.0     35.0     23.0       34.0       41.0
# 4        1.0        0.0        0.0      2.0      2.0        2.0        3.0
#
#    M20A24_03  M25A29_03  M30A34_03  M35A39_03  M40A44_03  M45A49_03  \
# 0       46.0       80.0       99.0      101.0       62.0       50.0
# 1      331.0      365.0      344.0      387.0      422.0      400.0
# 2       42.0       48.0       60.0       56.0       70.0       50.0
# 3       44.0       55.0       55.0       63.0       64.0       66.0
# 4        6.0        7.0        9.0        7.0        8.0        3.0
#
#    M50A54_03  M55A59_03  M60A64_03  M65A69_03  M70A74_03  M75A79_03  \
# 0       40.0       41.0       27.0       26.0       15.0       16.0
# 1      338.0      277.0      204.0      250.0      216.0      185.0
# 2       37.0       40.0       32.0       35.0       32.0       26.0
# 3       39.0       29.0       24.0       26.0       40.0       27.0
# 4        7.0        5.0        3.0        3.0        8.0        4.0
#
#    M80A84_03  M85A89_03  M90A94_03  M95A99_03  M100YMS_03
# 0       24.0        6.0        6.0        5.0         0.0
# 1      136.0       67.0       25.0        6.0         2.0
# 2       24.0       10.0        7.0        1.0         0.0
# 3       22.0       11.0        4.0        0.0         0.0
# 4        4.0        0.0        0.0        0.0         0.0

# %% [markdown]
# Rename columns for year 2003:

# %%
df_join_03_cols = [elem[:-3] for elem in df_join_03.columns]
df_join_03.columns = df_join_03_cols

# %%
df_join_03 = df_join_03.rename(columns = {"NAT2":"NAT"})

# %%
df_join_03.head()
# Out:
#     NAT   H0A4   H5A9  H10A14  H15A19  H20A24  H25A29  H30A34  H35A39  H40A44  \
# 0  34.0   64.0   32.0    41.0    36.0    52.0    96.0   124.0    98.0    69.0
# 1  68.0  155.0  175.0   231.0   276.0   420.0   370.0   321.0   380.0   412.0
# 2  17.0   39.0   36.0    39.0    38.0    41.0    47.0    59.0    73.0    76.0
# 3  20.0   25.0   32.0    36.0    38.0    45.0    54.0    56.0    63.0    60.0
# 4   3.0    4.0    4.0     1.0     2.0     1.0     6.0    11.0     8.0    10.0
#
#    H45A49  H50A54  H55A59  H60A64  H65A69  H70A74  H75A79  H80A84  H85A89  \
# 0    57.0    53.0    44.0    36.0    28.0    24.0    14.0     7.0     5.0
# 1   359.0   427.0   318.0   203.0   211.0   207.0   143.0    86.0    36.0
# 2    68.0    45.0    48.0    38.0    53.0    39.0    19.0    14.0    15.0
# 3    60.0    44.0    40.0    25.0    30.0    30.0    14.0    21.0     2.0
# 4     5.0     6.0     2.0     5.0     8.0     6.0     4.0     2.0     1.0
#
#    H90A94  H95A99  H100MS   M0A4   M5A9  M10A14  M15A19  M20A24  M25A29  \
# 0     5.0     0.0     0.0   61.0   42.0    40.0    35.0    46.0    80.0
# 1    11.0     2.0     0.0  176.0  173.0   217.0   291.0   331.0   365.0
# 2     2.0     0.0     0.0   33.0   28.0    31.0    38.0    42.0    48.0
# 3     4.0     0.0     0.0   35.0   23.0    34.0    41.0    44.0    55.0
# 4     1.0     0.0     0.0    2.0    2.0     2.0     3.0     6.0     7.0
#
#    M30A34  M35A39  M40A44  M45A49  M50A54  M55A59  M60A64  M65A69  M70A74  \
# 0    99.0   101.0    62.0    50.0    40.0    41.0    27.0    26.0    15.0
# 1   344.0   387.0   422.0   400.0   338.0   277.0   204.0   250.0   216.0
# 2    60.0    56.0    70.0    50.0    37.0    40.0    32.0    35.0    32.0
# 3    55.0    63.0    64.0    66.0    39.0    29.0    24.0    26.0    40.0
# 4     9.0     7.0     8.0     3.0     7.0     5.0     3.0     3.0     8.0
#
#    M75A79  M80A84  M85A89  M90A94  M95A99  M100YMS
# 0    16.0    24.0     6.0     6.0     5.0      0.0
# 1   185.0   136.0    67.0    25.0     6.0      2.0
# 2    26.0    24.0    10.0     7.0     1.0      0.0
# 3    27.0    22.0    11.0     4.0     0.0      0.0
# 4     4.0     4.0     0.0     0.0     0.0      0.0

# %%
df_join_03.shape
# Out:
# (3854, 43)

# %% [markdown]
# Subdataframe for year 2010:

# %%
df_join_10 = df_join[df_join_10_cols]

# %% [markdown]
# Rename columns:

# %%
df_join_10_cols = [elem[:-3] for elem in df_join_10.columns]
df_join_10.columns = df_join_10_cols

# %%
df_join_10 = df_join_10.rename(columns = {"NAT2":"NAT"})

# %%
df_join_10.head()
# Out:
#     NAT   H0A4   H5A9  H10A14  H15A19  H20A24  H25A29  H30A34  H35A39  H40A44  \
# 0  47.0  118.0  104.0    53.0    48.0    46.0    80.0   172.0   204.0   148.0
# 1  93.0  236.0  192.0   205.0   221.0   294.0   379.0   444.0   346.0   409.0
# 2  14.0   43.0   42.0    41.0    29.0    35.0    35.0    48.0    65.0    60.0
# 3  28.0   53.0   55.0    44.0    39.0    40.0    57.0   110.0    82.0    72.0
# 4   2.0    9.0    3.0     2.0     4.0     3.0     2.0    10.0    19.0     9.0
#
#    H45A49  H50A54  H55A59  H60A64  H65A69  H70A74  H75A79  H80A84  H85A89  \
# 0   119.0    73.0    71.0    37.0    49.0    31.0    22.0    14.0     5.0
# 1   418.0   400.0   395.0   328.0   245.0   166.0   183.0   120.0    47.0
# 2    72.0    70.0    57.0    48.0    32.0    45.0    29.0    26.0     7.0
# 3    72.0    60.0    67.0    48.0    29.0    26.0    23.0    17.0    13.0
# 4    16.0     6.0     3.0     6.0     5.0     7.0     6.0     0.0     2.0
#
#    H90A94  H95A99  H100MS   M0A4   M5A9  M10A14  M15A19  M20A24  M25A29  \
# 0     1.0     0.0     0.0  129.0   96.0    65.0    46.0    55.0    70.0
# 1    17.0     2.0     0.0  195.0  193.0   195.0   200.0   289.0   344.0
# 2     5.0     1.0     0.0   37.0   41.0    32.0    26.0    36.0    37.0
# 3     1.0     0.0     1.0   43.0   43.0    31.0    32.0    49.0    68.0
# 4     0.0     0.0     0.0    9.0    7.0     2.0     2.0     4.0     6.0
#
#    M30A34  M35A39  M40A44  M45A49  M50A54  M55A59  M60A64  M65A69  M70A74  \
# 0   152.0   182.0   149.0   103.0    58.0    53.0    41.0    41.0    19.0
# 1   368.0   371.0   381.0   426.0   417.0   357.0   290.0   211.0   215.0
# 2    53.0    46.0    51.0    74.0    58.0    39.0    42.0    31.0    27.0
# 3   106.0    70.0    82.0    76.0    65.0    47.0    39.0    31.0    18.0
# 4     8.0    16.0    14.0     4.0     9.0     8.0     1.0     8.0     3.0
#
#    M75A79  M80A84  M85A89  M90A94  M95A99  M100YMS
# 0    27.0    12.0    13.0     7.0     0.0      1.0
# 1   221.0   178.0   108.0    36.0     8.0      0.0
# 2    29.0    24.0    12.0     9.0     3.0      0.0
# 3    42.0    25.0    27.0    10.0     4.0      1.0
# 4     7.0     2.0     3.0     0.0     0.0      0.0

# %% [markdown]
# Concat both datfarames:

# %%
df = pd.concat([df_join_03, df_join_10])
df.head()
# Out:
#     NAT   H0A4   H5A9  H10A14  H15A19  H20A24  H25A29  H30A34  H35A39  H40A44  \
# 0  34.0   64.0   32.0    41.0    36.0    52.0    96.0   124.0    98.0    69.0
# 1  68.0  155.0  175.0   231.0   276.0   420.0   370.0   321.0   380.0   412.0
# 2  17.0   39.0   36.0    39.0    38.0    41.0    47.0    59.0    73.0    76.0
# 3  20.0   25.0   32.0    36.0    38.0    45.0    54.0    56.0    63.0    60.0
# 4   3.0    4.0    4.0     1.0     2.0     1.0     6.0    11.0     8.0    10.0
#
#    H45A49  H50A54  H55A59  H60A64  H65A69  H70A74  H75A79  H80A84  H85A89  \
# 0    57.0    53.0    44.0    36.0    28.0    24.0    14.0     7.0     5.0
# 1   359.0   427.0   318.0   203.0   211.0   207.0   143.0    86.0    36.0
# 2    68.0    45.0    48.0    38.0    53.0    39.0    19.0    14.0    15.0
# 3    60.0    44.0    40.0    25.0    30.0    30.0    14.0    21.0     2.0
# 4     5.0     6.0     2.0     5.0     8.0     6.0     4.0     2.0     1.0
#
#    H90A94  H95A99  H100MS   M0A4   M5A9  M10A14  M15A19  M20A24  M25A29  \
# 0     5.0     0.0     0.0   61.0   42.0    40.0    35.0    46.0    80.0
# 1    11.0     2.0     0.0  176.0  173.0   217.0   291.0   331.0   365.0
# 2     2.0     0.0     0.0   33.0   28.0    31.0    38.0    42.0    48.0
# 3     4.0     0.0     0.0   35.0   23.0    34.0    41.0    44.0    55.0
# 4     1.0     0.0     0.0    2.0    2.0     2.0     3.0     6.0     7.0
#
#    M30A34  M35A39  M40A44  M45A49  M50A54  M55A59  M60A64  M65A69  M70A74  \
# 0    99.0   101.0    62.0    50.0    40.0    41.0    27.0    26.0    15.0
# 1   344.0   387.0   422.0   400.0   338.0   277.0   204.0   250.0   216.0
# 2    60.0    56.0    70.0    50.0    37.0    40.0    32.0    35.0    32.0
# 3    55.0    63.0    64.0    66.0    39.0    29.0    24.0    26.0    40.0
# 4     9.0     7.0     8.0     3.0     7.0     5.0     3.0     3.0     8.0
#
#    M75A79  M80A84  M85A89  M90A94  M95A99  M100YMS
# 0    16.0    24.0     6.0     6.0     5.0      0.0
# 1   185.0   136.0    67.0    25.0     6.0      2.0
# 2    26.0    24.0    10.0     7.0     1.0      0.0
# 3    27.0    22.0    11.0     4.0     0.0      0.0
# 4     4.0     4.0     0.0     0.0     0.0      0.0

# %% [markdown]
# Select target variable and predictors:

# %%
target = df["NAT"]
predictors = df[df.columns[1:]]

# %% [markdown]
# Train-test partition:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(predictors, target,
                                                    test_size = 0.33,
                                                    random_state = 0)

# %%
print('Training data shape:\nX_train: %s\ny_train: %s\n' % (X_train.shape, y_train.shape))
print('Test data shape:\nX_test: %s\ny_test: %s' % (X_test.shape, y_test.shape))
# Out:
# Training data shape:
# X_train: (5164, 42)
# y_train: (5164,)
#
# Test data shape:
# X_test: (2544, 42)
# y_test: (2544,)

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
# Try standard regression methods: linear regression
lin_reg = LinearRegression()

# %%
# Fit training data
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
y_pred_lin_reg = lin_reg.predict(X_test)

# %% [markdown]
# Create functoin to evaluate models

# %%
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error  as mse
from sklearn.metrics import r2_score            as r2

def evaluate(obs, pred, method):
  """
  Function to evaluate regression models
    
  Parameters
  ----------
  obs : array-like
      Target variable observed. Continuous variable..
  pred : array-like
      Predicted values for target variable. Continuous variable.
  method: string
      Model type
  
  Returns
  -------
  my_mae: float
      Mean absolute error regression loss.
  my_mse: float
      Mean squared error regression loss.
  my_r2: float
        R2 (coefficient of determination) regression score function.
  """

  # Round predicted values to the nearest integer
  pred_round = np.rint(pred)
  # If negative, convert to 0
  pred_noneg = [0 if x <= 0 else x for x in pred_round]
    
  # Compute mean absolute error
  my_mae = mae(obs, pred_noneg)
  print("MAE for %s: %f" % (method, my_mae))
    
  # Compute mean squared error
  my_mse = mse(obs, pred_noneg)
  print("MSE for %s: %f" % (method, my_mse))
    
  # Compute R2
  my_r2 = r2(obs, pred_noneg)
  print("R2  for %s: %f" % (method, my_r2))
    
  # Count the number of negative predicted values
  neg = len([x for x in pred if x < 0])
  print("Negative predictions:      %i" % neg)

  return([my_mae, my_mse, my_r2])

# %%
from matplotlib import pyplot as plt
def plotter(obs, pred, method):
  """
  Function to plot obseved vs predicted values for the target variable.
    
  Parameters
  ----------
  obs : array-like
      Target variable observed. Continuous variable..
  pred : array-like
      Predicted values for target variable. Continuous variable.
  method: string
      Model type
  
  Returns
  -------
  None
  """
  plt.rcParams["figure.figsize"] = [7.50, 3.50]
  plt.rcParams["figure.autolayout"] = True
  pred_round = np.rint(pred)
  pred_noneg = [0 if x <= 0 else x for x in pred_round]
  overlapping = 0.150
  plt.tick_params(
      axis='x',          
      which='both',
      bottom=False,    
      top=False,       
      labelbottom=False) 
  plt.ylabel("Nº births")
  plt.plot(obs.values, lw = 5, alpha = overlapping)
  plt.plot(pred_noneg, c = "red")
  plt.title("NATALITY MODEL" + method.upper())
  plt.legend(["obs", "pred"])
  plt.show()

  temp = pd.DataFrame({"obs"  : list(obs),
                      "pred" :  list(pred)})
  
  temp = temp[temp["obs"] <= 10]

  plt.tick_params(
      axis='x',          
      which='both',
      bottom=False,    
      top=False,       
      labelbottom=False) 
  plt.ylabel("Nº births")
  plt.scatter(np.linspace(1, len(temp["obs"]), len(temp["obs"]), endpoint=True), 
           temp["obs"],  alpha = overlapping, marker = "o")
  plt.scatter(np.linspace(1, len(temp["obs"]), len(temp["obs"]), endpoint=True),
           [0 if x <= 0 else x for x in temp["pred"]], c = "red", marker = "o")
  plt.title("NATALITY MODEL (zoom). " + method.upper())
  plt.legend(["obs", "pred"], loc = "upper right")
  plt.ylim(-1, 15)
  plt.show()

# %% [markdown]
# Evaluate linear regression:

# %%
eval_lr = evaluate(y_test, y_pred_lin_reg, "linear regression")
# Out:
# MAE for linear regression: 2.468160
# MSE for linear regression: 89.278695
# R2  for linear regression: 0.998124
# Negative predictions:      436

# %% [markdown]
# Plot results:

# %%
plotter(y_test, y_pred_lin_reg, "linear regression")

# %% [markdown]
# ## KNN

# %% [markdown]
# GridSearchCV to find best number of neighbors:

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

grid_params = {"n_neighbors" : list(range(1,16))}

knn_cv = GridSearchCV(KNeighborsRegressor(), 
                       grid_params, 
                       verbose = 1,
                       cv = 3,
                       n_jobs = -1)

knn = knn_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits

# %%
knn.best_params_
# Out:
# {'n_neighbors': 3}

# %% [markdown]
# Build up model and predict:

# %%
knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# %% [markdown]
# Evaluate:

# %%
eval_knn = evaluate(y_test, y_pred_knn, "KNN")
# Out:
# MAE for KNN: 5.954403
# MSE for KNN: 12123.726415
# R2  for KNN: 0.745291
# Negative predictions:      0

# %% [markdown]
# Plot:

# %%
plotter(y_test, y_pred_knn, "KNN")

# %% [markdown]
# ## Neural Network 1

# %% [markdown]
# Load needed libraries:

# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Callback for early stopping in order to avoid overfitting:

# %%
my_callbacks = [
                tf.keras.callbacks.EarlyStopping(monitor = "val_loss",
                                                 patience = 10,
                                                 min_delta = 0,
                                                 verbose = 1,
                                                 restore_best_weights = True)
]

# %% [markdown]
# Build up model:

# %%
tf.keras.backend.clear_session()
model = Sequential()
model.add(Dense(units = 5, activation = 'relu', input_dim = 42))
model.add(Dense(units = 5, activation = 'relu'))
model.add(Dense(1, activation = "linear"))


model.compile(loss = 'mean_squared_error',
              metrics = ["mean_absolute_error"],
              optimizer = 'adam')

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# Fit on training data:

# %%
hist_1 = model.fit(X_train, y_train,
            epochs = 50,
            validation_split = 0.2,
            verbose = 1,
            callbacks = my_callbacks)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 1s 3ms/step - loss: 29679.2656 - mean_absolute_error: 24.4030 - val_loss: 27695.9043 - val_mean_absolute_error: 23.8737
# Epoch 2/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10448.7510 - mean_absolute_error: 16.2247 - val_loss: 27690.8633 - val_mean_absolute_error: 23.8362
# Epoch 3/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10438.2305 - mean_absolute_error: 16.1730 - val_loss: 27687.5020 - val_mean_absolute_error: 23.8148
# Epoch 4/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10435.5156 - mean_absolute_error: 16.1518 - val_loss: 27683.8711 - val_mean_absolute_error: 23.7965
# Epoch 5/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10433.0693 - mean_absolute_error: 16.1336 - val_loss: 27680.3066 - val_mean_absolute_error: 23.7793
# Epoch 6/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10430.5889 - mean_absolute_error: 16.1160 - val_loss: 27676.6113 - val_mean_absolute_error: 23.7620
# Epoch 7/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10428.0693 - mean_absolute_error: 16.0983 - val_loss: 27672.8320 - val_mean_absolute_error: 23.7448
# Epoch 8/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10425.5732 - mean_absolute_error: 16.0799 - val_loss: 27669.0137 - val_mean_absolute_error: 23.7275
# Epoch 9/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10423.0117 - mean_absolute_error: 16.0634 - val_loss: 27665.3730 - val_mean_absolute_error: 23.7102
# Epoch 10/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10420.4775 - mean_absolute_error: 16.0457 - val_loss: 27661.5938 - val_mean_absolute_error: 23.6920
# Epoch 11/50
# 130/130 [==============================] - 0s 2ms/step - loss: 10417.9180 - mean_absolute_error: 16.0268 - val_loss: 27657.7969 - val_mean_absolute_error: 23.6725
# Epoch 12/50
# 130/130 [==============================] - 0s 2ms/step - loss: 7352.0273 - mean_absolute_error: 13.7634 - val_loss: 3850.0540 - val_mean_absolute_error: 9.9925
# Epoch 13/50
# 130/130 [==============================] - 0s 2ms/step - loss: 298.3930 - mean_absolute_error: 4.5581 - val_loss: 407.6669 - val_mean_absolute_error: 4.3796
# Epoch 14/50
# 130/130 [==============================] - 0s 2ms/step - loss: 292.7836 - mean_absolute_error: 3.9298 - val_loss: 416.4688 - val_mean_absolute_error: 4.3746
# Epoch 15/50
# 130/130 [==============================] - 0s 2ms/step - loss: 314.8654 - mean_absolute_error: 3.8701 - val_loss: 473.8925 - val_mean_absolute_error: 4.5313
# Epoch 16/50
# 130/130 [==============================] - 0s 2ms/step - loss: 269.6967 - mean_absolute_error: 3.7564 - val_loss: 766.0405 - val_mean_absolute_error: 5.1591
# Epoch 17/50
# 130/130 [==============================] - 0s 2ms/step - loss: 229.1226 - mean_absolute_error: 3.7028 - val_loss: 1070.7014 - val_mean_absolute_error: 5.6983
# Epoch 18/50
# 130/130 [==============================] - 0s 2ms/step - loss: 269.1208 - mean_absolute_error: 3.8198 - val_loss: 563.4679 - val_mean_absolute_error: 4.7418
# Epoch 19/50
# 130/130 [==============================] - 0s 2ms/step - loss: 228.0263 - mean_absolute_error: 3.6778 - val_loss: 486.4052 - val_mean_absolute_error: 4.5305
# Epoch 20/50
# 130/130 [==============================] - 0s 2ms/step - loss: 232.9577 - mean_absolute_error: 3.6844 - val_loss: 600.7439 - val_mean_absolute_error: 4.8039
# Epoch 21/50
# 130/130 [==============================] - 0s 2ms/step - loss: 228.9716 - mean_absolute_error: 3.6763 - val_loss: 503.1414 - val_mean_absolute_error: 4.5657
# Epoch 22/50
# 130/130 [==============================] - 0s 2ms/step - loss: 248.2001 - mean_absolute_error: 3.7554 - val_loss: 391.4712 - val_mean_absolute_error: 4.2526
# Epoch 23/50
# 130/130 [==============================] - 0s 2ms/step - loss: 271.6941 - mean_absolute_error: 3.7295 - val_loss: 591.1215 - val_mean_absolute_error: 4.7578
# Epoch 24/50
# 130/130 [==============================] - 0s 2ms/step - loss: 230.2349 - mean_absolute_error: 3.6303 - val_loss: 563.2354 - val_mean_absolute_error: 4.7036
# Epoch 25/50
# 130/130 [==============================] - 0s 2ms/step - loss: 240.6896 - mean_absolute_error: 3.5527 - val_loss: 520.3414 - val_mean_absolute_error: 4.5646
# Epoch 26/50
# 130/130 [==============================] - 0s 2ms/step - loss: 204.5014 - mean_absolute_error: 3.4845 - val_loss: 789.0335 - val_mean_absolute_error: 5.1231
# Epoch 27/50
# 130/130 [==============================] - 0s 2ms/step - loss: 212.9277 - mean_absolute_error: 3.6926 - val_loss: 1090.2258 - val_mean_absolute_error: 5.7305
# Epoch 28/50
# 130/130 [==============================] - 0s 2ms/step - loss: 245.5124 - mean_absolute_error: 3.6130 - val_loss: 905.2842 - val_mean_absolute_error: 5.3732
# Epoch 29/50
# 130/130 [==============================] - 0s 2ms/step - loss: 229.9432 - mean_absolute_error: 3.5786 - val_loss: 395.1798 - val_mean_absolute_error: 4.2547
# Epoch 30/50
# 130/130 [==============================] - 0s 2ms/step - loss: 198.1768 - mean_absolute_error: 3.4495 - val_loss: 497.3662 - val_mean_absolute_error: 4.4896
# Epoch 31/50
# 130/130 [==============================] - 0s 2ms/step - loss: 205.0320 - mean_absolute_error: 3.5197 - val_loss: 377.1129 - val_mean_absolute_error: 4.1797
# Epoch 32/50
# 130/130 [==============================] - 0s 2ms/step - loss: 156.7610 - mean_absolute_error: 3.3972 - val_loss: 326.2887 - val_mean_absolute_error: 4.3051
# Epoch 33/50
# 130/130 [==============================] - 0s 2ms/step - loss: 234.5475 - mean_absolute_error: 3.6724 - val_loss: 313.5268 - val_mean_absolute_error: 3.9325
# Epoch 34/50
# 130/130 [==============================] - 1s 5ms/step - loss: 201.0121 - mean_absolute_error: 3.6065 - val_loss: 434.2100 - val_mean_absolute_error: 4.3250
# Epoch 35/50
# 130/130 [==============================] - 0s 3ms/step - loss: 160.1752 - mean_absolute_error: 3.4331 - val_loss: 268.5706 - val_mean_absolute_error: 3.8862
# Epoch 36/50
# 130/130 [==============================] - 0s 2ms/step - loss: 167.7314 - mean_absolute_error: 3.3933 - val_loss: 1508.5063 - val_mean_absolute_error: 6.3240
# Epoch 37/50
# 130/130 [==============================] - 0s 2ms/step - loss: 829.1312 - mean_absolute_error: 5.3837 - val_loss: 889.8462 - val_mean_absolute_error: 5.4076
# Epoch 38/50
# 130/130 [==============================] - 0s 2ms/step - loss: 171.9040 - mean_absolute_error: 3.4773 - val_loss: 344.2491 - val_mean_absolute_error: 4.1374
# Epoch 39/50
# 130/130 [==============================] - 0s 2ms/step - loss: 173.9889 - mean_absolute_error: 3.3740 - val_loss: 354.2055 - val_mean_absolute_error: 4.1085
# Epoch 40/50
# 130/130 [==============================] - 0s 2ms/step - loss: 152.3359 - mean_absolute_error: 3.3062 - val_loss: 265.7227 - val_mean_absolute_error: 3.8077
# Epoch 41/50
# 130/130 [==============================] - 0s 2ms/step - loss: 195.7744 - mean_absolute_error: 3.3546 - val_loss: 452.5867 - val_mean_absolute_error: 4.3267
# Epoch 42/50
# 130/130 [==============================] - 0s 2ms/step - loss: 137.6883 - mean_absolute_error: 3.2684 - val_loss: 295.2051 - val_mean_absolute_error: 3.8437
# Epoch 43/50
# 130/130 [==============================] - 0s 2ms/step - loss: 156.0204 - mean_absolute_error: 3.2770 - val_loss: 311.5797 - val_mean_absolute_error: 3.8967
# Epoch 44/50
# 130/130 [==============================] - 0s 2ms/step - loss: 149.2612 - mean_absolute_error: 3.1693 - val_loss: 880.7560 - val_mean_absolute_error: 5.1960
# Epoch 45/50
# 130/130 [==============================] - 0s 2ms/step - loss: 149.0244 - mean_absolute_error: 3.2010 - val_loss: 239.8706 - val_mean_absolute_error: 3.6568
# Epoch 46/50
# 130/130 [==============================] - 0s 2ms/step - loss: 144.7309 - mean_absolute_error: 3.1582 - val_loss: 278.3819 - val_mean_absolute_error: 3.7231
# Epoch 47/50
# 130/130 [==============================] - 0s 2ms/step - loss: 160.9854 - mean_absolute_error: 3.1689 - val_loss: 231.0473 - val_mean_absolute_error: 3.6787
# Epoch 48/50
# 130/130 [==============================] - 0s 2ms/step - loss: 111.9510 - mean_absolute_error: 3.0536 - val_loss: 369.4644 - val_mean_absolute_error: 3.9595
# Epoch 49/50
# 130/130 [==============================] - 0s 2ms/step - loss: 278.1399 - mean_absolute_error: 3.4954 - val_loss: 270.4340 - val_mean_absolute_error: 3.6788
# Epoch 50/50
# 130/130 [==============================] - 0s 2ms/step - loss: 177.9128 - mean_absolute_error: 3.2216 - val_loss: 476.5040 - val_mean_absolute_error: 4.1790

# %% [markdown]
# Plot curves:

# %%
from matplotlib import pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18,9))
  
fig.suptitle('ANN MODEL 1')

ax1.plot(hist_1.history['mean_absolute_error'])
ax1.plot(hist_1.history['val_mean_absolute_error'])
ax1.title.set_text('Mean Absolute Error')
ax1.set_ylabel('MAE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'val'], loc='upper left')
#ax1.show()

ax2.plot(hist_1.history['loss'])
ax2.plot(hist_1.history['val_loss'])
ax2.title.set_text('Loss: Mean Squared Error')
ax2.set_ylabel('MSE')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'val'], loc='upper left')
#ax2.show()

# %% [markdown]
# Predict:

# %%
y_pred_ann = model.predict(X_test)

# %% [markdown]
# Evaluate:

# %%
eval_ann_1 = evaluate(y_test, y_pred_ann.flatten(), "ANN")
# Out:
# MAE for ANN: 4.349843
# MSE for ANN: 950.636006
# R2  for ANN: 0.980028
# Negative predictions:      140

# %% [markdown]
# Plor observed vs predicted:

# %%
plotter(y_test, y_pred_ann, "ANN")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /usr/local/lib/python3.7/dist-packages/numpy/ma/core.py:2830: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   order=order, subok=True, ndmin=ndmin)

# %% [markdown]
# ## Neural Network 2:

# %% [markdown]
# Build up model:

# %%
tf.keras.backend.clear_session()
model_2 = Sequential()
model_2.add(Dense(units = 32, activation = 'relu', input_dim = 42))
model_2.add(Dense(units = 16, activation = 'relu'))
model_2.add(Dense(units = 8, activation = 'relu'))
model_2.add(Dense(1, activation = "linear"))


model_2.compile(loss = 'mean_squared_error',
              metrics = ["mean_absolute_error"],
              optimizer = 'adam')

# %%
tf.keras.utils.plot_model(model_2)

# %% [markdown]
# Fit on training data:

# %%
hist_2 = model_2.fit(X_train, y_train,
            epochs = 50,
            validation_split = 0.2,
            verbose = 1,
            callbacks = my_callbacks)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 1s 3ms/step - loss: 804.2870 - mean_absolute_error: 4.8463 - val_loss: 486.8373 - val_mean_absolute_error: 4.2926
# Epoch 2/50
# 130/130 [==============================] - 0s 2ms/step - loss: 368.8776 - mean_absolute_error: 3.5623 - val_loss: 517.3832 - val_mean_absolute_error: 4.0602
# Epoch 3/50
# 130/130 [==============================] - 0s 2ms/step - loss: 197.7305 - mean_absolute_error: 3.3175 - val_loss: 7064.6499 - val_mean_absolute_error: 11.8572
# Epoch 4/50
# 130/130 [==============================] - 0s 2ms/step - loss: 1188.8916 - mean_absolute_error: 5.9293 - val_loss: 243.7738 - val_mean_absolute_error: 3.5223
# Epoch 5/50
# 130/130 [==============================] - 0s 2ms/step - loss: 162.9971 - mean_absolute_error: 2.9899 - val_loss: 413.3166 - val_mean_absolute_error: 3.6867
# Epoch 6/50
# 130/130 [==============================] - 0s 2ms/step - loss: 307.0846 - mean_absolute_error: 3.0592 - val_loss: 2005.7111 - val_mean_absolute_error: 6.6510
# Epoch 7/50
# 130/130 [==============================] - 0s 2ms/step - loss: 125.7137 - mean_absolute_error: 2.9829 - val_loss: 481.4987 - val_mean_absolute_error: 3.7648
# Epoch 8/50
# 130/130 [==============================] - 0s 2ms/step - loss: 106.1888 - mean_absolute_error: 2.6399 - val_loss: 236.0405 - val_mean_absolute_error: 3.1828
# Epoch 9/50
# 130/130 [==============================] - 0s 2ms/step - loss: 123.9677 - mean_absolute_error: 2.7540 - val_loss: 169.4923 - val_mean_absolute_error: 3.0261
# Epoch 10/50
# 130/130 [==============================] - 0s 2ms/step - loss: 126.8521 - mean_absolute_error: 2.7036 - val_loss: 191.3401 - val_mean_absolute_error: 3.0614
# Epoch 11/50
# 130/130 [==============================] - 0s 2ms/step - loss: 103.8246 - mean_absolute_error: 2.5255 - val_loss: 149.7105 - val_mean_absolute_error: 2.9004
# Epoch 12/50
# 130/130 [==============================] - 0s 2ms/step - loss: 84.1236 - mean_absolute_error: 2.4976 - val_loss: 217.4468 - val_mean_absolute_error: 3.1269
# Epoch 13/50
# 130/130 [==============================] - 0s 2ms/step - loss: 114.9031 - mean_absolute_error: 2.6366 - val_loss: 154.9607 - val_mean_absolute_error: 2.9074
# Epoch 14/50
# 130/130 [==============================] - 0s 2ms/step - loss: 72.0222 - mean_absolute_error: 2.4210 - val_loss: 259.8637 - val_mean_absolute_error: 3.1700
# Epoch 15/50
# 130/130 [==============================] - 0s 2ms/step - loss: 187.8637 - mean_absolute_error: 3.1111 - val_loss: 10322.7920 - val_mean_absolute_error: 14.1500
# Epoch 16/50
# 130/130 [==============================] - 0s 2ms/step - loss: 342.1313 - mean_absolute_error: 3.8528 - val_loss: 623.3841 - val_mean_absolute_error: 4.1812
# Epoch 17/50
# 130/130 [==============================] - 0s 2ms/step - loss: 116.0480 - mean_absolute_error: 2.7855 - val_loss: 188.0390 - val_mean_absolute_error: 3.1612
# Epoch 18/50
# 130/130 [==============================] - 0s 2ms/step - loss: 129.9245 - mean_absolute_error: 2.9498 - val_loss: 195.1221 - val_mean_absolute_error: 3.0920
# Epoch 19/50
# 130/130 [==============================] - 0s 2ms/step - loss: 199.5931 - mean_absolute_error: 3.1279 - val_loss: 276.6640 - val_mean_absolute_error: 3.3665
# Epoch 20/50
# 130/130 [==============================] - 0s 2ms/step - loss: 63.5516 - mean_absolute_error: 2.4126 - val_loss: 1240.1486 - val_mean_absolute_error: 5.3157
# Epoch 21/50
# 123/130 [===========================>..] - ETA: 0s - loss: 202.3484 - mean_absolute_error: 2.9924Restoring model weights from the end of the best epoch: 11.
# 130/130 [==============================] - 0s 2ms/step - loss: 193.7100 - mean_absolute_error: 2.9457 - val_loss: 216.2917 - val_mean_absolute_error: 3.1722
# Epoch 21: early stopping

# %% [markdown]
# Plot curves:

# %%
from matplotlib import pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18,9))
  
fig.suptitle('ANN MODEL 2')

ax1.plot(hist_2.history['mean_absolute_error'])
ax1.plot(hist_2.history['val_mean_absolute_error'])
ax1.title.set_text('Mean Absolute Error')
ax1.set_ylabel('MAE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'val'], loc='upper left')
#ax1.show()

ax2.plot(hist_2.history['loss'])
ax2.plot(hist_2.history['val_loss'])
ax2.title.set_text('Loss: Mean Squared Error')
ax2.set_ylabel('MSE')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'val'], loc='upper left')
#ax2.show()

# %% [markdown]
# Predict:

# %%
y_pred_ann_2 = model_2.predict(X_test)

# %% [markdown]
# Evaluate:

# %%
eval_ann_2 = evaluate(y_test, y_pred_ann_2.flatten(), "ANN_2")
# Out:
# MAE for ANN_2: 2.580975
# MSE for ANN_2: 151.235063
# R2  for ANN_2: 0.996823
# Negative predictions:      82

# %% [markdown]
# Plot observed vs predicted:

# %%
plotter(y_test, y_pred_ann_2, "ANN")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /usr/local/lib/python3.7/dist-packages/numpy/ma/core.py:2830: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   order=order, subok=True, ndmin=ndmin)

# %% [markdown]
# ## Neural Network 3

# %% [markdown]
# Build up model:

# %%
tf.keras.backend.clear_session()


input = keras.Input(shape = (42,))
layer_1 = Dense(units = 10, activation = "relu")(input)
tower_1 = Dense(units = 5 , activation = "relu")(layer_1)
tower_2 = Dense(units = 5 , activation = "relu")(layer_1)
merged = keras.layers.concatenate([tower_1, tower_2], axis=1)
out = Dense(1, activation='relu')(merged)
model_3 = keras.Model(input, out)



model_3.compile(loss = 'mean_squared_error',
              metrics = ["mean_absolute_error"],
              optimizer = 'adam')

# %%
tf.keras.utils.plot_model(model_3)

# %% [markdown]
# Fit on training data:

# %%
hist_3 = model_3.fit(X_train, y_train,
            epochs = 50,
            validation_split = 0.2,
            verbose = 1,
            callbacks = my_callbacks)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 1s 3ms/step - loss: 1450.1989 - mean_absolute_error: 7.0364 - val_loss: 5295.2769 - val_mean_absolute_error: 7.6952
# Epoch 2/50
# 130/130 [==============================] - 0s 2ms/step - loss: 1178.3440 - mean_absolute_error: 5.7308 - val_loss: 638.4994 - val_mean_absolute_error: 5.1379
# Epoch 3/50
# 130/130 [==============================] - 0s 2ms/step - loss: 1238.6965 - mean_absolute_error: 5.6611 - val_loss: 482.2782 - val_mean_absolute_error: 4.3930
# Epoch 4/50
# 130/130 [==============================] - 0s 2ms/step - loss: 426.9144 - mean_absolute_error: 4.2642 - val_loss: 967.5897 - val_mean_absolute_error: 5.2442
# Epoch 5/50
# 130/130 [==============================] - 0s 2ms/step - loss: 955.4980 - mean_absolute_error: 4.7508 - val_loss: 2842.0417 - val_mean_absolute_error: 7.8684
# Epoch 6/50
# 130/130 [==============================] - 0s 2ms/step - loss: 591.5257 - mean_absolute_error: 4.4294 - val_loss: 460.7567 - val_mean_absolute_error: 4.2382
# Epoch 7/50
# 130/130 [==============================] - 0s 2ms/step - loss: 620.3954 - mean_absolute_error: 4.3391 - val_loss: 501.1586 - val_mean_absolute_error: 4.4348
# Epoch 8/50
# 130/130 [==============================] - 0s 2ms/step - loss: 390.9616 - mean_absolute_error: 3.8875 - val_loss: 870.2192 - val_mean_absolute_error: 5.2618
# Epoch 9/50
# 130/130 [==============================] - 0s 2ms/step - loss: 485.3682 - mean_absolute_error: 4.1774 - val_loss: 845.7607 - val_mean_absolute_error: 5.1929
# Epoch 10/50
# 130/130 [==============================] - 0s 2ms/step - loss: 446.6739 - mean_absolute_error: 3.7708 - val_loss: 658.4971 - val_mean_absolute_error: 4.7986
# Epoch 11/50
# 130/130 [==============================] - 0s 2ms/step - loss: 358.7680 - mean_absolute_error: 3.8268 - val_loss: 448.7738 - val_mean_absolute_error: 4.1666
# Epoch 12/50
# 130/130 [==============================] - 0s 2ms/step - loss: 473.6185 - mean_absolute_error: 4.0234 - val_loss: 469.0768 - val_mean_absolute_error: 4.2655
# Epoch 13/50
# 130/130 [==============================] - 0s 2ms/step - loss: 304.7693 - mean_absolute_error: 3.7293 - val_loss: 539.5951 - val_mean_absolute_error: 4.4537
# Epoch 14/50
# 130/130 [==============================] - 0s 2ms/step - loss: 416.8662 - mean_absolute_error: 3.7987 - val_loss: 521.5616 - val_mean_absolute_error: 4.3918
# Epoch 15/50
# 130/130 [==============================] - 0s 2ms/step - loss: 301.3386 - mean_absolute_error: 3.5437 - val_loss: 502.4900 - val_mean_absolute_error: 4.3178
# Epoch 16/50
# 130/130 [==============================] - 0s 2ms/step - loss: 271.2388 - mean_absolute_error: 3.4697 - val_loss: 390.0810 - val_mean_absolute_error: 3.7026
# Epoch 17/50
# 130/130 [==============================] - 0s 2ms/step - loss: 254.2714 - mean_absolute_error: 3.4383 - val_loss: 455.9740 - val_mean_absolute_error: 3.6149
# Epoch 18/50
# 130/130 [==============================] - 0s 2ms/step - loss: 466.4840 - mean_absolute_error: 3.8084 - val_loss: 386.7527 - val_mean_absolute_error: 3.8438
# Epoch 19/50
# 130/130 [==============================] - 0s 2ms/step - loss: 259.5412 - mean_absolute_error: 3.4624 - val_loss: 386.7665 - val_mean_absolute_error: 3.8402
# Epoch 20/50
# 130/130 [==============================] - 0s 2ms/step - loss: 546.8135 - mean_absolute_error: 3.9448 - val_loss: 1174.7090 - val_mean_absolute_error: 5.4330
# Epoch 21/50
# 130/130 [==============================] - 0s 2ms/step - loss: 228.8113 - mean_absolute_error: 3.2510 - val_loss: 424.5437 - val_mean_absolute_error: 3.4734
# Epoch 22/50
# 130/130 [==============================] - 0s 2ms/step - loss: 249.7496 - mean_absolute_error: 3.3009 - val_loss: 1184.0469 - val_mean_absolute_error: 5.7003
# Epoch 23/50
# 130/130 [==============================] - 0s 2ms/step - loss: 181.1478 - mean_absolute_error: 3.1523 - val_loss: 375.9635 - val_mean_absolute_error: 3.4435
# Epoch 24/50
# 130/130 [==============================] - 0s 2ms/step - loss: 210.9162 - mean_absolute_error: 3.2492 - val_loss: 390.0733 - val_mean_absolute_error: 3.4651
# Epoch 25/50
# 130/130 [==============================] - 0s 2ms/step - loss: 250.2686 - mean_absolute_error: 3.2895 - val_loss: 1927.9408 - val_mean_absolute_error: 6.7917
# Epoch 26/50
# 130/130 [==============================] - 0s 2ms/step - loss: 299.3976 - mean_absolute_error: 3.4823 - val_loss: 672.0082 - val_mean_absolute_error: 4.1714
# Epoch 27/50
# 130/130 [==============================] - 0s 2ms/step - loss: 223.2569 - mean_absolute_error: 3.2881 - val_loss: 421.5234 - val_mean_absolute_error: 3.4175
# Epoch 28/50
# 130/130 [==============================] - 0s 2ms/step - loss: 184.3751 - mean_absolute_error: 3.1027 - val_loss: 383.2373 - val_mean_absolute_error: 3.8388
# Epoch 29/50
# 130/130 [==============================] - 0s 2ms/step - loss: 243.1197 - mean_absolute_error: 3.1815 - val_loss: 353.9622 - val_mean_absolute_error: 3.3583
# Epoch 30/50
# 130/130 [==============================] - 0s 2ms/step - loss: 277.8402 - mean_absolute_error: 3.2895 - val_loss: 816.1449 - val_mean_absolute_error: 4.9011
# Epoch 31/50
# 130/130 [==============================] - 0s 2ms/step - loss: 153.0506 - mean_absolute_error: 3.0399 - val_loss: 651.0379 - val_mean_absolute_error: 4.5426
# Epoch 32/50
# 130/130 [==============================] - 0s 2ms/step - loss: 273.9825 - mean_absolute_error: 3.2600 - val_loss: 618.3072 - val_mean_absolute_error: 4.4765
# Epoch 33/50
# 130/130 [==============================] - 0s 2ms/step - loss: 139.5503 - mean_absolute_error: 2.9084 - val_loss: 327.5004 - val_mean_absolute_error: 3.3369
# Epoch 34/50
# 130/130 [==============================] - 0s 2ms/step - loss: 186.4644 - mean_absolute_error: 3.0874 - val_loss: 351.1936 - val_mean_absolute_error: 3.2145
# Epoch 35/50
# 130/130 [==============================] - 0s 2ms/step - loss: 147.4172 - mean_absolute_error: 2.9574 - val_loss: 426.6357 - val_mean_absolute_error: 3.4414
# Epoch 36/50
# 130/130 [==============================] - 0s 2ms/step - loss: 185.8356 - mean_absolute_error: 2.9540 - val_loss: 347.1720 - val_mean_absolute_error: 3.1902
# Epoch 37/50
# 130/130 [==============================] - 0s 2ms/step - loss: 268.6221 - mean_absolute_error: 3.1452 - val_loss: 408.4648 - val_mean_absolute_error: 3.3867
# Epoch 38/50
# 130/130 [==============================] - 0s 2ms/step - loss: 219.3114 - mean_absolute_error: 3.0702 - val_loss: 275.6014 - val_mean_absolute_error: 3.2625
# Epoch 39/50
# 130/130 [==============================] - 0s 2ms/step - loss: 102.4549 - mean_absolute_error: 2.7056 - val_loss: 270.8867 - val_mean_absolute_error: 3.2332
# Epoch 40/50
# 130/130 [==============================] - 0s 2ms/step - loss: 93.1115 - mean_absolute_error: 2.6392 - val_loss: 344.8494 - val_mean_absolute_error: 3.1961
# Epoch 41/50
# 130/130 [==============================] - 0s 2ms/step - loss: 100.8713 - mean_absolute_error: 2.6765 - val_loss: 251.9090 - val_mean_absolute_error: 3.1616
# Epoch 42/50
# 130/130 [==============================] - 0s 2ms/step - loss: 125.1500 - mean_absolute_error: 2.8567 - val_loss: 392.7881 - val_mean_absolute_error: 3.8219
# Epoch 43/50
# 130/130 [==============================] - 0s 2ms/step - loss: 379.7755 - mean_absolute_error: 3.3559 - val_loss: 678.9572 - val_mean_absolute_error: 4.2555
# Epoch 44/50
# 130/130 [==============================] - 0s 2ms/step - loss: 448.2927 - mean_absolute_error: 3.3489 - val_loss: 458.8634 - val_mean_absolute_error: 3.5209
# Epoch 45/50
# 130/130 [==============================] - 0s 2ms/step - loss: 82.3739 - mean_absolute_error: 2.6542 - val_loss: 363.6213 - val_mean_absolute_error: 3.3058
# Epoch 46/50
# 130/130 [==============================] - 0s 2ms/step - loss: 109.1885 - mean_absolute_error: 2.7004 - val_loss: 266.8237 - val_mean_absolute_error: 3.1825
# Epoch 47/50
# 130/130 [==============================] - 0s 2ms/step - loss: 123.2659 - mean_absolute_error: 2.6818 - val_loss: 255.9422 - val_mean_absolute_error: 3.2352
# Epoch 48/50
# 130/130 [==============================] - 0s 2ms/step - loss: 128.5983 - mean_absolute_error: 2.7001 - val_loss: 249.8378 - val_mean_absolute_error: 3.1067
# Epoch 49/50
# 130/130 [==============================] - 0s 2ms/step - loss: 90.8112 - mean_absolute_error: 2.6389 - val_loss: 234.9617 - val_mean_absolute_error: 3.0929
# Epoch 50/50
# 130/130 [==============================] - 0s 2ms/step - loss: 92.1759 - mean_absolute_error: 2.6192 - val_loss: 223.9645 - val_mean_absolute_error: 3.1229

# %% [markdown]
# Plot curves:

# %%
from matplotlib import pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18,9))
  
fig.suptitle('ANN MODEL 3')

ax1.plot(hist_3.history['mean_absolute_error'])
ax1.plot(hist_3.history['val_mean_absolute_error'])
ax1.title.set_text('Mean Absolute Error')
ax1.set_ylabel('MAE')
ax1.set_xlabel('epoch')
ax1.legend(['train', 'val'], loc='upper left')
#ax1.show()

ax2.plot(hist_3.history['loss'])
ax2.plot(hist_3.history['val_loss'])
ax2.title.set_text('Loss: Mean Squared Error')
ax2.set_ylabel('MSE')
ax2.set_xlabel('epoch')
ax2.legend(['train', 'val'], loc='upper left')
#ax2.show()

# %% [markdown]
# Predict:

# %%
y_pred_ann_3 = model_3.predict(X_test)

# %% [markdown]
# Evaluate:

# %%
eval_ann_3 = evaluate(y_test, y_pred_ann_3.flatten(), "ANN_3")
# Out:
# MAE for ANN_3: 2.952044
# MSE for ANN_3: 400.732704
# R2  for ANN_3: 0.991581
# Negative predictions:      0

# %% [markdown]
# Plot observed vs predicted:

# %%
plotter(y_test, y_pred_ann_3, "ANN")
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# /usr/local/lib/python3.7/dist-packages/numpy/ma/core.py:2830: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   order=order, subok=True, ndmin=ndmin)

# %% [markdown]
# ## Scalable Kernel Methods
#
# ### Kernel Ridge Regression + (RFF, Nyström) + GridSearchCV
#
# These models completely fail.

# %%
import time
import warnings

import seaborn as sns; sns.set(style="ticks", color_codes=True)

from IPython.display import Markdown

from sklearn import svm
from sklearn import pipeline
from sklearn.kernel_approximation import Nystroem
from sklearn.kernel_approximation import RBFSampler
from sklearn.datasets import fetch_openml
from sklearn.decomposition import PCA

# %%
def krr_rff_nys_gridsearch(train_predictors, train_observed, test_predictors, test_observed, feature,
                           n_components = [100], gamma = [1], cv_val = 2):
    """
    Function to apply approximate kernel ridge regression with RFF or Nyström approximation.
    GridSearchCV is used to find optimum parameters.
    
    Parameters
    ----------
    train_predictors : array-like
        Predictor variables for the given training data.
    train_observed : array-like
        Target variable observed for the given training data. Contonuous variable.
    test_predictor: array-like
        Predictor variables for the given test data.
    test_observed: array-like
        Target variable observed for the given test data. Continuous variable. 
    feature: string {'RFF' or 'Nystroem'}
        Feature map to approximate a kernel map using a subset os the training data.
    n_components: int
        Number of features to construct. How many data points will be used to construct
        the mapping. If none is give, 100 will be used.
    gamma: float
        Gamma parameter for the RBF, laplacian, polynomial, exponential chi2 and 
        sigmoid kernels. If none is given, 1 will be used.
    cv_val: int, cross-validation generator or an iterable
        Determines the cross-validation splitting startaefy. None as default
        
    Returns
    -------
    mae_error: float
        Mean absolute error regression loss.
    ellapsed_time: float
        Time needed to fit training data.
    grid_cv.best_params_: dict
        Parameter setting that gave the best result on the hold out data.
    """
    # Define feature map
    if feature == "Nystroem":
        feature_map = Nystroem()
    elif feature  == "RFF":
        feature_map = RBFSampler()
    else: # Raise exception if other features are desired
        raise Exception("No feature map is available for feature=" + feature +
                        ". Use feature=\"Nystroem\" or feature=\"RFF\"")
        
    if not(len(n_components) > 1 or len(gamma) > 1): # Raise warning
        warnings.warn("Kernel map approximation : " + feature.upper() +
                      ". No exhaustive search will be applied."
                      " At least one of the arguments \"n_components\", \"gamma\","
                      " must be a list of length > 1")
        
    approx_krr = pipeline.Pipeline([('feature_map', feature_map),
                                    ('ridge', LinearRegression())])
    
    parameters = {"feature_map__n_components" : n_components,
                  "feature_map__gamma" : gamma}
    
    t0 = time.time()
    grid_cv = GridSearchCV(approx_krr, 
                           param_grid = parameters, 
                           cv = cv_val, 
                           scoring = 'neg_mean_squared_error')
    grid_cv.fit(train_predictors, train_observed)
    ellapsed_time = time.time() - t0
  
    y_pred = grid_cv.predict(test_predictors)

    plotter(test_observed, y_pred, feature)
    
    mae_error = mae(test_observed, y_pred)
    print('MAE for %s with GridSearchCV: %.4f'% (feature, mae_error))

    mse_error = mse(test_observed, y_pred)
    print('MSE for %s with GridSearchCV: %.4f'% (feature, mse_error))

    r2_error = r2(test_observed, y_pred)
    print('R2 for %s with GridSearchCV: %.4f'% (feature, r2_error))
    
    return(mae_error, mse_error, r2, ellapsed_time, grid_cv.best_params_)

# %%
nys_mae_cv, nys_mse_cv, nys_r2_cv, nys_time_cv, nys_best = krr_rff_nys_gridsearch(train_predictors = X_train,
                                                           train_observed = y_train,
                                                           test_predictors = X_test,
                                                           test_observed = y_test,
                                                           feature = "Nystroem",
                                                           n_components = [50,100,250,500,1000],
                                                           gamma = list(np.linspace(0,1,11)),
                                                           cv_val = 2)
# Out:
# MAE for Nystroem with GridSearchCV: 31.5140
# MSE for Nystroem with GridSearchCV: 47619.7089
# R2 for Nystroem with GridSearchCV: -0.0004

# %%
rff_mae_cv, rff_mse_cv, rff_r2_cv, rff_time_cv, rff_best = krr_rff_nys_gridsearch(train_predictors = X_train,
                                                           train_observed = y_train,
                                                           test_predictors = X_test,
                                                           test_observed = y_test,
                                                           feature = "RFF",
                                                           n_components = [50,100,250,500,1000],
                                                           gamma = list(np.linspace(0,1,11)),
                                                           cv_val = 2)
# Out:
# MAE for RFF with GridSearchCV: 34.1180
# MSE for RFF with GridSearchCV: 47779.7688
# R2 for RFF with GridSearchCV: -0.0038

# %% [markdown]
# ## Random Forest

# %% [markdown]
# Load required libraires:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import ParameterGrid
from sklearn.inspection import permutation_importance
import multiprocessing

# %% [markdown]
# Search for best hyperparameters:

# %%
# Grid for hyperparameters
param_grid = ParameterGrid(
                {'n_estimators': [100, 125, 150, 200, 300, 500],
                 'max_features': [3, 5, 7, 9],
                 'max_depth'   : [None, 3, 10, 20, 50]
                }
             )

# For loop to fit models with every combination of hyperparamaeters
resultados = {'params': [], 'oob_r2': []}

for params in param_grid:
    
    modelo = RandomForestRegressor(
                oob_score    = True,
                n_jobs       = -1,
                random_state = 123,
                ** params
             )
    
    modelo.fit(X_train, y_train)
    
    resultados['params'].append(params)
    resultados['oob_r2'].append(modelo.oob_score_)
    print(f"Modelo: {params} \u2713")

# Results
resultados = pd.DataFrame(resultados)
resultados = pd.concat([resultados, resultados['params'].apply(pd.Series)], axis=1)
resultados = resultados.drop(columns = 'params')
resultados = resultados.sort_values('oob_r2', ascending=False)
resultados.head(4)
# Out:
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 100} ✓
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 125} ✓
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 150} ✓
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 200} ✓
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 300} ✓
# Modelo: {'max_depth': None, 'max_features': 3, 'n_estimators': 500} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 100} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 125} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 150} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 200} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 300} ✓
# Modelo: {'max_depth': None, 'max_features': 5, 'n_estimators': 500} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 100} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 125} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 150} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 200} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 300} ✓
# Modelo: {'max_depth': None, 'max_features': 7, 'n_estimators': 500} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 100} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 125} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 150} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 200} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 300} ✓
# Modelo: {'max_depth': None, 'max_features': 9, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 3, 'max_features': 3, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 3, 'max_features': 5, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 3, 'max_features': 7, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 3, 'max_features': 9, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 10, 'max_features': 3, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 10, 'max_features': 5, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 10, 'max_features': 7, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 10, 'max_features': 9, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 20, 'max_features': 3, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 20, 'max_features': 5, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 20, 'max_features': 7, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 20, 'max_features': 9, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 50, 'max_features': 3, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 50, 'max_features': 5, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 50, 'max_features': 7, 'n_estimators': 500} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 100} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 125} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 150} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 200} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 300} ✓
# Modelo: {'max_depth': 50, 'max_features': 9, 'n_estimators': 500} ✓
#       oob_r2  max_depth  max_features  n_estimators
# 48  0.981396       10.0           3.0         100.0
# 68  0.981359       10.0           9.0         150.0
# 69  0.981335       10.0           9.0         200.0
# 93  0.981208       20.0           9.0         200.0

# %%
# Best hyperparameters fot out-of-bag error
print("--------------------------------------------")
print("Mejores hiperparámetros encontrados (oob-r2)")
print("--------------------------------------------")
print(resultados.iloc[0,0], ":", resultados.iloc[0,:]['oob_r2'], "R2")
# Out:
# --------------------------------------------
# Mejores hiperparámetros encontrados (oob-r2)
# --------------------------------------------
# 0.9813960042857579 : 0.9813960042857579 R2

# %%
max_depth =  resultados.iloc[0]["max_depth"]
print("Max depth %f" % max_depth)

n_estimators =  resultados.iloc[0]["n_estimators"]
print("n_estimators %f" % n_estimators)

max_features = resultados.iloc[0]["max_features"]
print("max_features %f" % max_features)
# Out:
# Max depth 10.000000
# n_estimators 100.000000
# max_features 3.000000

# %% [markdown]
# Build up model:

# %%
modelo_rf = RandomForestRegressor(
            n_estimators = int(n_estimators),
            criterion    = 'squared_error',
            max_depth    = int(max_depth),
            max_features = int(max_features),
            oob_score    = False,
            n_jobs       = -1,
            random_state = 123
         )

# %% [markdown]
# Fit on training data:

# %%
modelo_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, max_features=3, n_jobs=-1, random_state=123)

# %% [markdown]
# Predict:

# %%
pred_rf = modelo.predict(X = X_test)

# %% [markdown]
# Evaluate:

# %%
eval_rf = evaluate(y_test, pred_rf, "RANDOM FOREST")
# Out:
# MAE for RANDOM FOREST: 5.667846
# MSE for RANDOM FOREST: 12308.001179
# R2  for RANDOM FOREST: 0.741420
# Negative predictions:      0

# %% [markdown]
# Plot observed vs predicted:

# %%
plotter(y_test, pred_rf, "RANDOM FOREST")

# %% [markdown]
# ## Compare results:

# %%
data = [eval_lr,
        eval_knn,
        eval_ann_1,
        eval_ann_2,
        eval_ann_3,
        eval_rf]
df_results = pd.DataFrame(data, columns = ["MAE", "MSE", "R2"])
df_results["METHOD"] = ["LinearRegression", "KNN", "ANN1", "ANN2", "ANN3", "RandomForest"]
df_results.set_index("METHOD")
# Out:
#                        MAE           MSE        R2
# METHOD
# LinearRegression  2.468160     89.278695  0.998124
# KNN               5.954403  12123.726415  0.745291
# ANN1              4.349843    950.636006  0.980028
# ANN2              2.580975    151.235063  0.996823
# ANN3              2.952044    400.732704  0.991581
# RandomForest      5.667846  12308.001179  0.741420
